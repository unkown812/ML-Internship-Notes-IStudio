# %% [markdown]
# # Univariate Feature Imputation

# %% [raw]
# Simple imputer provides the basic stratagies for imputing missing values. Missing Values can be
# imputed with a provided consatant value or using statistics (mean, mode ,median) of each
# column in which the missing values are located.

# %%
import numpy as np
import pandas as pd
X=np.array([[np.nan,2],[6,np.nan],[7,6]])
X
# Out:
# array([[nan,  2.],
#        [ 6., nan],
#        [ 7.,  6.]])

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="mean")
imp.fit_transform(X)
# Out:
# array([[6.5, 2. ],
#        [6. , 4. ],
#        [7. , 6. ]])

# %%
13/2
# Out:
# 6.5

# %%
# for categorical features:

df=pd.DataFrame([["a","x"],[np.nan,"y"],["a",np.nan],["b","y"]],dtype="category")

# %%
df
# Out:
#      0    1
# 0    a    x
# 1  NaN    y
# 2    a  NaN
# 3    b    y

# %%
imp_1=SimpleImputer(strategy="most_frequent")
print(imp_1.fit_transform(df))
# Out:
# [['a' 'x']
#  ['a' 'y']
#  ['a' 'y']
#  ['b' 'y']]

# %% [markdown]
# # Multivariate feature imputation:

# %% [raw]
# IterativeImputer class which models each feature with missing values as a fucntion of other
# feature and uses that estimate for imputation.

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imp_iter=IterativeImputer(max_iter=10,random_state=10)
imp_iter.fit_transform(X)
# Out:
# array([[5.000012, 2.      ],
#        [6.      , 3.999988],
#        [7.      , 6.      ]])

# %% [markdown]
# # nearest neighbour Imputer

# %%
Y=np.array([[1,2,np.nan],[3,4,3],[np.nan,6,5],[8,8,7]])
Y
# Out:
# array([[ 1.,  2., nan],
#        [ 3.,  4.,  3.],
#        [nan,  6.,  5.],
#        [ 8.,  8.,  7.]])

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer(n_neighbors=2,weights="uniform")
imputer.fit_transform(Y)
# Out:
# array([[1. , 2. , 4. ],
#        [3. , 4. , 3. ],
#        [5.5, 6. , 5. ],
#        [8. , 8. , 7. ]])
